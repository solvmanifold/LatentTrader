# %%
import pandas as pd
import requests
from datetime import datetime, timedelta

def fetch_gdelt_data(start_date, end_date):
    base_url = "http://data.gdeltproject.org/events/"
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')
    sentiment_data = []

    for single_date in date_range:
        date_str = single_date.strftime("%Y%m%d")
        url = f"{base_url}{date_str}.export.CSV.zip"
        
        try:
            response = requests.get(url)
            if response.status_code == 200:
                df = pd.read_csv(url, compression='zip', sep='\t', header=None, low_memory=False)
                
                # Column indices for sentiment
                avgtone_index = 34
                
                avg_tone = df[avgtone_index].mean()
                sentiment_data.append({
                    "date": single_date,
                    "avg_tone": avg_tone
                })
            else:
                print(f"Data not found for {date_str}")
        except Exception as e:
            print(f"Error fetching data for {date_str}: {e}")

    return pd.DataFrame(sentiment_data)

# Define the date range
start_date = "2025-01-01"
end_date = "2025-02-03"

# Fetch the data
sentiment_df = fetch_gdelt_data(start_date, end_date)

# Display the resulting dataframe
print(sentiment_df.head())
# Out:
#         date  avg_tone
# 0 2025-01-01 -1.930671
# 1 2025-01-02 -2.037406
# 2 2025-01-03 -2.245253
# 3 2025-01-04 -2.257718
# 4 2025-01-05 -2.189166

# %%
import pandas as pd

# %%
# Load the Parquet file
df = pd.read_parquet("reports/TechnicalScorer.parquet")
df
# Out:
#          date            model  \
# 0  2024-05-17  TechnicalScorer
# 1  2024-05-18  TechnicalScorer
# 2  2024-05-19  TechnicalScorer
# 3  2024-05-22  TechnicalScorer
# 4  2024-05-23  TechnicalScorer
# 5  2025-05-23  TechnicalScorer
# 6  2025-05-29  TechnicalScorer
# 7  2025-05-30  TechnicalScorer
# 8  2025-05-31  TechnicalScorer
# 9  2025-06-02  TechnicalScorer
#
#                                          top_tickers  \
# 0                    [BAX, CRL, GPN, LULU, ARE, AMP]
# 1                                                 []
# 2                                                 []
# 3                   [JBHT, SLB, TGT, ULTA, BMY, BAX]
# 4                    [ALGN, BMY, CZR, CLX, ITW, MCD]
# 5  [CPRT, KHC, AFL, ARE, AMCR, AVB, CRL, CPAY, FS...
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                               scores  \
# 0  [4.5454545, 4.5454545, 4.5454545, 4.5454545, 3...
# 1                                                 []
# 2                                                 []
# 3  [6.363636, 6.363636, 6.363636, 6.363636, 5.454...
# 4  [6.363636, 6.363636, 6.363636, 6.363636, 6.363...
# 5  [6.363636, 6.363636, 4.5454545, 4.5454545, 4.5...
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                            report_md
# 0  # Trading Advisor Report\n\nGenerated on: 2025...
# 1  # Trading Advisor Report\n\nGenerated on: 2025...
# 2  # Trading Advisor Report\n\nGenerated on: 2025...
# 3  # Trading Advisor Report\n\nGenerated on: 2025...
# 4  # Trading Advisor Report\n\nGenerated on: 2025...
# 5  # Trading Advisor Report\n\nGenerated on: 2025...
# 6  # Trading Advisor Report\n\nGenerated on: 2025...
# 7  # Trading Advisor Report\n\nGenerated on: 2025...
# 8  # Trading Advisor Report\n\nGenerated on: 2025...
# 9  # Trading Advisor Report\n\nGenerated on: 2025...

# %%
df.iloc[-1]
# Out:
# Open                                                      337.515015
# High                                                      338.649994
# Low                                                       333.209991
# Close                                                     337.045013
# Volume                                                      25402923
# Dividends                                                        0.0
# Stock Splits                                                     0.0
# RSI                                                        63.058972
# MACD                                                       19.993312
# MACD_Signal                                                17.951582
# MACD_Hist                                                    2.04173
# BB_Upper                                                   368.68139
# BB_Lower                                                  254.744116
# BB_Middle                                                 311.712753
# BB_Pband                                                    0.722335
# SMA_20                                                    311.712753
# SMA_50                                                    276.857102
# SMA_100                                                    315.91345
# SMA_200                                                   299.195075
# EMA_100                                                   300.940377
# EMA_200                                                   291.755394
# Prev_Volume                                               96761500.0
# score                                                       4.545455
# score_details      {'analyst_targets': 0.0, 'bollinger': 0.0, 'ma...
# analyst_targets    {"current_price": 336.9788, "median_target": 2...
# Name: 2025-05-23 00:00:00, dtype: object

# %%
import pandas as pd

# Load the Parquet file
df = pd.read_parquet("reports/TechnicalScorer.parquet")

print(len(df))
print(df.iloc[0].name)
# Out:
# 500
# 0

# %% [markdown]
# # Trading Advisor Report
#
# Generated on: 2025-05-23 16:23:11
#
# ## Current Positions
#
# ### CRL
# **Technical Score:** 3.64/10
# **OHLC:** Open: 134.21, High: 135.62, Low: 133.85, Close: 134.79
# **Current Position**
# **Technical Indicators:**
# - RSI: 51.68
# - MACD value: 2.77
# - MACD signal: 2.03
# - MACD histogram: 0.74
# - BOLLINGER_BANDS upper: 153.53
# - BOLLINGER_BANDS middle: 131.72
# - BOLLINGER_BANDS lower: 109.92
# - MOVING_AVERAGES sma_20: 131.72
# **Analyst Targets:**
# - Median: $159.28
# - Range: $70.0 - $215.0
#
# ### CPAY
# **Technical Score:** 2.73/10
# **OHLC:** Open: 319.87, High: 323.46, Low: 321.35, Close: 322.78
# **Current Position**
# **Technical Indicators:**
# - RSI: 43.45
# - MACD value: 2.13
# - MACD signal: 3.71
# - MACD histogram: -1.58
# - BOLLINGER_BANDS upper: 357.23
# - BOLLINGER_BANDS middle: 333.69
# - BOLLINGER_BANDS lower: 310.15
# - MOVING_AVERAGES sma_20: 333.69
# **Analyst Targets:**
# - Median: $393.63
# - Range: $330.0 - $445.0
#
# ### FSLR
# **Technical Score:** 2.73/10
# **OHLC:** Open: 154.0, High: 160.2, Low: 152.66, Close: 159.44
# **Current Position**
# **Technical Indicators:**
# - RSI: 54.44
# - MACD value: 8.79
# - MACD signal: 8.99
# - MACD histogram: -0.2
# - BOLLINGER_BANDS upper: 196.69
# - BOLLINGER_BANDS middle: 151.79
# - BOLLINGER_BANDS lower: 106.89
# - MOVING_AVERAGES sma_20: 151.79
# **Analyst Targets:**
# - Median: $200.05
# - Range: $100.0 - $304.0
#
# ### REGN
# **Technical Score:** 2.73/10
# **OHLC:** Open: 586.85, High: 588.51, Low: 582.37, Close: 587.14
# **Current Position**
# **Technical Indicators:**
# - RSI: 49.53
# - MACD value: 0.33
# - MACD signal: -4.21
# - MACD histogram: 4.54
# - BOLLINGER_BANDS upper: 627.57
# - BOLLINGER_BANDS middle: 582.97
# - BOLLINGER_BANDS lower: 538.36
# - MOVING_AVERAGES sma_20: 582.97
# **Analyst Targets:**
# - Median: $797.21
# - Range: $535.0 - $958.0
#
# ## New Technical Picks (Top 6) for 2025-05-23 (TechnicalScorer)
#
# ### CPRT
# **Technical Score:** 6.36/10
# **OHLC:** Open: 57.98, High: 58.07, Low: 54.44, Close: 54.53
# **Technical Indicators:**
# - RSI: 28.19
# - MACD value: 0.18
# - MACD signal: 0.92
# - MACD histogram: -0.74
# - BOLLINGER_BANDS upper: 64.9
# - BOLLINGER_BANDS middle: 61.23
# - BOLLINGER_BANDS lower: 57.56
# - MOVING_AVERAGES sma_20: 61.23
# **Analyst Targets:**
# - Median: $61.51
# - Range: $56.0 - $67.0
#
# ### KHC
# **Technical Score:** 6.36/10
# **OHLC:** Open: 26.48, High: 26.52, Low: 26.03, Close: 26.23
# **Technical Indicators:**
# - RSI: 29.7
# - MACD value: -0.68
# - MACD signal: -0.53
# - MACD histogram: -0.14
# - BOLLINGER_BANDS upper: 29.53
# - BOLLINGER_BANDS middle: 27.95
# - BOLLINGER_BANDS lower: 26.36
# - MOVING_AVERAGES sma_20: 27.95
# **Analyst Targets:**
# - Median: $31.56
# - Range: $26.0 - $53.34
#
# ### AFL
# **Technical Score:** 4.55/10
# **OHLC:** Open: 102.0, High: 102.48, Low: 101.73, Close: 101.84
# **Technical Indicators:**
# - RSI: 38.11
# - MACD value: -0.85
# - MACD signal: -0.54
# - MACD histogram: -0.31
# - BOLLINGER_BANDS upper: 108.53
# - BOLLINGER_BANDS middle: 105.14
# - BOLLINGER_BANDS lower: 101.75
# - MOVING_AVERAGES sma_20: 105.14
# **Analyst Targets:**
# - Median: $106.0
# - Range: $94.0 - $120.0
#
# ### ARE
# **Technical Score:** 4.55/10
# **OHLC:** Open: 67.8, High: 68.48, Low: 67.8, Close: 68.2
# **Technical Indicators:**
# - RSI: 32.39
# - MACD value: -2.86
# - MACD signal: -2.93
# - MACD histogram: 0.07
# - BOLLINGER_BANDS upper: 76.64
# - BOLLINGER_BANDS middle: 72.43
# - BOLLINGER_BANDS lower: 68.21
# - MOVING_AVERAGES sma_20: 72.43
# **Analyst Targets:**
# - Median: $104.46
# - Range: $76.0 - $144.0
#
# ### AMCR
# **Technical Score:** 4.55/10
# **OHLC:** Open: 8.95, High: 8.98, Low: 8.92, Close: 8.93
# **Technical Indicators:**
# - RSI: 39.01
# - MACD value: -0.08
# - MACD signal: -0.06
# - MACD histogram: -0.02
# - BOLLINGER_BANDS upper: 9.55
# - BOLLINGER_BANDS middle: 9.24
# - BOLLINGER_BANDS lower: 8.92
# - MOVING_AVERAGES sma_20: 9.24
# **Analyst Targets:**
# - Median: $11.59
# - Range: $10.83 - $13.0
#
# ### AVB
# **Technical Score:** 4.55/10
# **OHLC:** Open: 199.4, High: 199.41, Low: 197.69, Close: 198.42
# **Technical Indicators:**
# - RSI: 39.48
# - MACD value: -1.08
# - MACD signal: -0.25
# - MACD histogram: -0.83
# - BOLLINGER_BANDS upper: 213.46
# - BOLLINGER_BANDS middle: 206.39
# - BOLLINGER_BANDS lower: 199.31
# - MOVING_AVERAGES sma_20: 206.39
# **Analyst Targets:**
# - Median: $234.0
# - Range: $220.0 - $255.0

# %%
df
# Out:
#                     date ticker     score
# 0    2024-05-23 00:00:00      A  2.727273
# 1    2024-05-23 00:00:00   AAPL  2.727273
# 2    2024-05-23 00:00:00   ABBV  3.636364
# 3    2024-05-23 00:00:00   ABNB  2.727273
# 4    2024-05-23 00:00:00    ABT  0.000000
# ..                   ...    ...       ...
# 495  2024-05-23 00:00:00    XYL  2.727273
# 496  2024-05-23 00:00:00    YUM  0.909091
# 497  2024-05-23 00:00:00    ZBH  3.636364
# 498  2024-05-23 00:00:00   ZBRA  1.818182
# 499  2024-05-23 00:00:00    ZTS  2.727273
#
# [500 rows x 3 columns]

# %%
import pandas as pd

# Load the Parquet file
df = pd.read_parquet("features/GOOGL_features.parquet")

print(len(df))
print(df.iloc[-1])
# Out:
# 1262
# Open                                                      167.839996
# High                                                      169.869995
# Low                                                       167.389999
# Close                                                     168.990005
# Volume                                                      17186772
# Dividends                                                        0.0
# Stock Splits                                                     0.0
# RSI                                                        55.998633
# MACD                                                         3.29387
# MACD_Signal                                                 2.722749
# MACD_Hist                                                   0.571121
# BB_Upper                                                  177.615916
# BB_Lower                                                  151.999085
# BB_Middle                                                   164.8075
# BB_Pband                                                    0.663272
# SMA_20                                                      164.8075
# SMA_50                                                    160.114001
# SMA_100                                                   171.616561
# SMA_200                                                   170.977352
# EMA_100                                                   167.472257
# EMA_200                                                    168.01591
# Prev_Volume                                                      NaN
# score                                                            NaN
# score_details                                                   None
# analyst_targets    {"current_price": 168.99, "median_target": 201...
# Name: 2025-06-02 00:00:00, dtype: object

# %%
df = pd.read_parquet("model_outputs/TechnicalScorer/AAPL.parquet")

# %%
df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2020-05-26   78.616095   78.795926   76.914974   76.970871  125522000
# 2020-05-27   76.827477   77.452025   76.086269   77.306213  112945200
# 2020-05-28   76.980580   78.601508   76.703544   77.340248  133560800
# 2020-05-29   77.583268   78.044999   76.907680   77.264915  153532400
# 2020-06-01   77.218738   78.336619   77.087507   78.215111   80791200
# ...                ...         ...         ...         ...        ...
# 2025-05-19  207.910004  209.479996  204.259995  208.779999   46140500
# 2025-05-20  207.669998  208.470001  205.029999  206.860001   42496600
# 2025-05-21  205.169998  207.039993  200.710007  202.089996   59211800
# 2025-05-22  200.710007  202.750000  199.699997  201.360001   46633900
# 2025-05-23  193.664993  197.699997  193.460007  195.990005   34393907
#
#             Dividends  Stock Splits        RSI      MACD  MACD_Signal  ...  \
# Date                                                                   ...
# 2020-05-26        0.0           0.0        NaN       NaN          NaN  ...
# 2020-05-27        0.0           0.0        NaN       NaN          NaN  ...
# 2020-05-28        0.0           0.0        NaN       NaN          NaN  ...
# 2020-05-29        0.0           0.0        NaN       NaN          NaN  ...
# 2020-06-01        0.0           0.0        NaN       NaN          NaN  ...
# ...               ...           ...        ...       ...          ...  ...
# 2025-05-19        0.0           0.0  52.173875  0.768095    -0.535925  ...
# 2025-05-20        0.0           0.0  50.044535  0.659609    -0.296818  ...
# 2025-05-21        0.0           0.0  45.117973  0.186582    -0.200138  ...
# 2025-05-22        0.0           0.0  44.397639 -0.244382    -0.208987  ...
# 2025-05-23        0.0           0.0  39.412716 -1.007623    -0.368714  ...
#
#              BB_Middle  BB_Pband      SMA_20      SMA_50     SMA_100  \
# Date
# 2020-05-26         NaN       NaN         NaN         NaN         NaN
# 2020-05-27         NaN       NaN         NaN         NaN         NaN
# 2020-05-28         NaN       NaN         NaN         NaN         NaN
# 2020-05-29         NaN       NaN         NaN         NaN         NaN
# 2020-06-01         NaN       NaN         NaN         NaN         NaN
# ...                ...       ...         ...         ...         ...
# 2025-05-19  206.398450  0.599838  206.398450  207.628971  222.960229
# 2025-05-20  206.767529  0.504022  206.767529  207.222529  222.482272
# 2025-05-21  206.655425  0.303764  206.655425  206.853313  221.927385
# 2025-05-22  206.318570  0.290502  206.318570  206.546597  221.357018
# 2025-05-23  205.667774  0.115344  205.667774  206.278289  220.767169
#
#                SMA_200     EMA_100     EMA_200  \
# Date
# 2020-05-26         NaN         NaN         NaN
# 2020-05-27         NaN         NaN         NaN
# 2020-05-28         NaN         NaN         NaN
# 2020-05-29         NaN         NaN         NaN
# 2020-06-01         NaN         NaN         NaN
# ...                ...         ...         ...
# 2025-05-19  225.628424  216.854282  217.715056
# 2025-05-20  225.576006  216.656376  217.607046
# 2025-05-21  225.492273  216.367933  217.452647
# 2025-05-22  225.457594  216.070746  217.292521
# 2025-05-23  225.406217  215.673107  217.080556
#
#                                               analyst_targets     score
# Date
# 2020-05-26                                               None  0.000000
# 2020-05-27                                               None  0.000000
# 2020-05-28                                               None  0.000000
# 2020-05-29                                               None  0.000000
# 2020-06-01                                               None  0.909091
# ...                                                       ...       ...
# 2025-05-19                                               None  1.818182
# 2025-05-20                                               None  1.818182
# 2025-05-21                                               None  2.727273
# 2025-05-22  {"current_price": 195.9312, "median_target": 2...  2.727273
# 2025-05-23  {"current_price": 195.99, "median_target": 228...  2.727273
#
# [1257 rows x 23 columns]

# %%
import os
import pandas as pd
from pathlib import Path

features_dir = Path("features")
min_rows = 1257

for file in features_dir.glob("*_features.parquet"):
    try:
        df = pd.read_parquet(file)
        if len(df) < min_rows:
            print(f"Deleting {file.name}: only {len(df)} rows (expected at least {min_rows})")
            file.unlink()
        else:
            print(f"{file.name}: {len(df)} rows (OK)")
    except Exception as e:
        print(f"Error reading {file.name}: {e} (deleting file)")
        file.unlink()
# Out:
# HON_features.parquet: 1257 rows (OK)
# HUBB_features.parquet: 1257 rows (OK)
# FDS_features.parquet: 1257 rows (OK)
# AXP_features.parquet: 1257 rows (OK)
# NI_features.parquet: 1257 rows (OK)
# PSX_features.parquet: 1257 rows (OK)
# CBRE_features.parquet: 1257 rows (OK)
# ED_features.parquet: 1257 rows (OK)
# HLT_features.parquet: 1257 rows (OK)
# AMZN_features.parquet: 1257 rows (OK)
# ABT_features.parquet: 1257 rows (OK)
# GLW_features.parquet: 1257 rows (OK)
# MS_features.parquet: 1257 rows (OK)
# AVB_features.parquet: 1257 rows (OK)
# BMY_features.parquet: 1257 rows (OK)
# NTRS_features.parquet: 1257 rows (OK)
# SPGI_features.parquet: 1257 rows (OK)
# CNP_features.parquet: 1257 rows (OK)
# SHW_features.parquet: 1257 rows (OK)
# MDLZ_features.parquet: 1257 rows (OK)
# Deleting COIN_features.parquet: only 1034 rows (expected at least 1257)
# CFG_features.parquet: 1257 rows (OK)
# JKHY_features.parquet: 1257 rows (OK)
# EQIX_features.parquet: 1257 rows (OK)
# CMCSA_features.parquet: 1257 rows (OK)
# MTD_features.parquet: 1257 rows (OK)
# BEN_features.parquet: 1257 rows (OK)
# GE_features.parquet: 1257 rows (OK)
# KLAC_features.parquet: 1257 rows (OK)
# CCL_features.parquet: 1257 rows (OK)
# WFC_features.parquet: 1257 rows (OK)
# CZR_features.parquet: 1257 rows (OK)
# LH_features.parquet: 1257 rows (OK)
# TKO_features.parquet: 1257 rows (OK)
# LOW_features.parquet: 1257 rows (OK)
# ODFL_features.parquet: 1257 rows (OK)
# LLY_features.parquet: 1257 rows (OK)
# WAB_features.parquet: 1257 rows (OK)
# NTAP_features.parquet: 1257 rows (OK)
# UBER_features.parquet: 1257 rows (OK)
# TDY_features.parquet: 1257 rows (OK)
# DOV_features.parquet: 1257 rows (OK)
# FDX_features.parquet: 1257 rows (OK)
# DIS_features.parquet: 1257 rows (OK)
# SWKS_features.parquet: 1257 rows (OK)
# PARA_features.parquet: 1257 rows (OK)
# GWW_features.parquet: 1257 rows (OK)
# HES_features.parquet: 1257 rows (OK)
# REG_features.parquet: 1257 rows (OK)
# L_features.parquet: 1257 rows (OK)
# GILD_features.parquet: 1257 rows (OK)
# ICE_features.parquet: 1257 rows (OK)
# PAYX_features.parquet: 1257 rows (OK)
# PEP_features.parquet: 1257 rows (OK)
# IQV_features.parquet: 1257 rows (OK)
# LW_features.parquet: 1257 rows (OK)
# JBHT_features.parquet: 1257 rows (OK)
# ETN_features.parquet: 1257 rows (OK)
# OTIS_features.parquet: 1257 rows (OK)
# URI_features.parquet: 1257 rows (OK)
# UNH_features.parquet: 1257 rows (OK)
# RMD_features.parquet: 1257 rows (OK)
# ALLE_features.parquet: 1257 rows (OK)
# ENPH_features.parquet: 1257 rows (OK)
# ADSK_features.parquet: 1257 rows (OK)
# ORLY_features.parquet: 1257 rows (OK)
# VICI_features.parquet: 1257 rows (OK)
# BA_features.parquet: 1257 rows (OK)
# IDXX_features.parquet: 1257 rows (OK)
# CME_features.parquet: 1257 rows (OK)
# DD_features.parquet: 1257 rows (OK)
# AEE_features.parquet: 1257 rows (OK)
# INVH_features.parquet: 1257 rows (OK)
# TER_features.parquet: 1257 rows (OK)
# ZBH_features.parquet: 1257 rows (OK)
# USB_features.parquet: 1257 rows (OK)
# NCLH_features.parquet: 1257 rows (OK)
# COP_features.parquet: 1257 rows (OK)
# AOS_features.parquet: 1257 rows (OK)
# HST_features.parquet: 1257 rows (OK)
# MAR_features.parquet: 1257 rows (OK)
# HAS_features.parquet: 1257 rows (OK)
# FE_features.parquet: 1257 rows (OK)
# Deleting GEHC_features.parquet: only 611 rows (expected at least 1257)
# DELL_features.parquet: 1257 rows (OK)
# JPM_features.parquet: 1257 rows (OK)
# SJM_features.parquet: 1257 rows (OK)
# AVY_features.parquet: 1257 rows (OK)
# TMUS_features.parquet: 1257 rows (OK)
# APH_features.parquet: 1257 rows (OK)
# GIS_features.parquet: 1257 rows (OK)
# JNPR_features.parquet: 1257 rows (OK)
# EBAY_features.parquet: 1257 rows (OK)
# FRT_features.parquet: 1257 rows (OK)
# WELL_features.parquet: 1257 rows (OK)
# Deleting SW_features.parquet: only 222 rows (expected at least 1257)
# PAYC_features.parquet: 1257 rows (OK)
# EXPD_features.parquet: 1257 rows (OK)
# LEN_features.parquet: 1257 rows (OK)
# NEM_features.parquet: 1257 rows (OK)
# Deleting VLTO_features.parquet: only 411 rows (expected at least 1257)
# TYL_features.parquet: 1257 rows (OK)
# PM_features.parquet: 1257 rows (OK)
# PNR_features.parquet: 1257 rows (OK)
# C_features.parquet: 1257 rows (OK)
# TFC_features.parquet: 1257 rows (OK)
# PFE_features.parquet: 1257 rows (OK)
# SNPS_features.parquet: 1257 rows (OK)
# Deleting KVUE_features.parquet: only 516 rows (expected at least 1257)
# CHTR_features.parquet: 1257 rows (OK)
# ALB_features.parquet: 1257 rows (OK)
# COO_features.parquet: 1257 rows (OK)
# BXP_features.parquet: 1257 rows (OK)
# MKTX_features.parquet: 1257 rows (OK)
# HPE_features.parquet: 1257 rows (OK)
# EXR_features.parquet: 1257 rows (OK)
# UPS_features.parquet: 1257 rows (OK)
# KR_features.parquet: 1257 rows (OK)
# HAL_features.parquet: 1257 rows (OK)
# CPRT_features.parquet: 1257 rows (OK)
# RL_features.parquet: 1257 rows (OK)
# LII_features.parquet: 1257 rows (OK)
# HPQ_features.parquet: 1257 rows (OK)
# PYPL_features.parquet: 1257 rows (OK)
# TSN_features.parquet: 1257 rows (OK)
# AJG_features.parquet: 1257 rows (OK)
# CHRW_features.parquet: 1257 rows (OK)
# BLDR_features.parquet: 1257 rows (OK)
# REGN_features.parquet: 1257 rows (OK)
# NDSN_features.parquet: 1257 rows (OK)
# CPT_features.parquet: 1257 rows (OK)
# F_features.parquet: 1257 rows (OK)
# ITW_features.parquet: 1257 rows (OK)
# SYK_features.parquet: 1257 rows (OK)
# PNW_features.parquet: 1257 rows (OK)
# GDDY_features.parquet: 1257 rows (OK)
# PH_features.parquet: 1257 rows (OK)
# ACN_features.parquet: 1257 rows (OK)
# EMN_features.parquet: 1257 rows (OK)
# CPAY_features.parquet: 1257 rows (OK)
# GEN_features.parquet: 1257 rows (OK)
# DECK_features.parquet: 1257 rows (OK)
# PNC_features.parquet: 1257 rows (OK)
# GD_features.parquet: 1257 rows (OK)
# FCX_features.parquet: 1257 rows (OK)
# VRTX_features.parquet: 1257 rows (OK)
# ANSS_features.parquet: 1257 rows (OK)
# UHS_features.parquet: 1257 rows (OK)
# MGM_features.parquet: 1257 rows (OK)
# EXC_features.parquet: 1257 rows (OK)
# XOM_features.parquet: 1257 rows (OK)
# SPG_features.parquet: 1257 rows (OK)
# DLR_features.parquet: 1257 rows (OK)
# BSX_features.parquet: 1257 rows (OK)
# IPG_features.parquet: 1257 rows (OK)
# TDG_features.parquet: 1257 rows (OK)
# WDC_features.parquet: 1257 rows (OK)
# ADP_features.parquet: 1257 rows (OK)
# ULTA_features.parquet: 1257 rows (OK)
# FAST_features.parquet: 1257 rows (OK)
# GPC_features.parquet: 1257 rows (OK)
# QCOM_features.parquet: 1257 rows (OK)
# VMC_features.parquet: 1257 rows (OK)
# DHI_features.parquet: 1257 rows (OK)
# COST_features.parquet: 1257 rows (OK)
# AZO_features.parquet: 1257 rows (OK)
# NKE_features.parquet: 1257 rows (OK)
# ABBV_features.parquet: 1257 rows (OK)
# VTRS_features.parquet: 1257 rows (OK)
# WDAY_features.parquet: 1257 rows (OK)
# MRK_features.parquet: 1257 rows (OK)
# IRM_features.parquet: 1257 rows (OK)
# PHM_features.parquet: 1257 rows (OK)
# DOC_features.parquet: 1257 rows (OK)
# ALL_features.parquet: 1257 rows (OK)
# NFLX_features.parquet: 1257 rows (OK)
# CAG_features.parquet: 1257 rows (OK)
# ROP_features.parquet: 1257 rows (OK)
# LULU_features.parquet: 1257 rows (OK)
# DOW_features.parquet: 1257 rows (OK)
# ROST_features.parquet: 1257 rows (OK)
# TRGP_features.parquet: 1257 rows (OK)
# AIG_features.parquet: 1257 rows (OK)
# NUE_features.parquet: 1257 rows (OK)
# TROW_features.parquet: 1257 rows (OK)
# LUV_features.parquet: 1257 rows (OK)
# RF_features.parquet: 1257 rows (OK)
# WY_features.parquet: 1257 rows (OK)
# GNRC_features.parquet: 1257 rows (OK)
# WST_features.parquet: 1257 rows (OK)
# MAS_features.parquet: 1257 rows (OK)
# MSCI_features.parquet: 1257 rows (OK)
# PPL_features.parquet: 1257 rows (OK)
# WM_features.parquet: 1257 rows (OK)
# MHK_features.parquet: 1257 rows (OK)
# SBAC_features.parquet: 1257 rows (OK)
# AXON_features.parquet: 1257 rows (OK)
# AMGN_features.parquet: 1257 rows (OK)
# DE_features.parquet: 1257 rows (OK)
# STX_features.parquet: 1257 rows (OK)
# TRMB_features.parquet: 1257 rows (OK)
# EQT_features.parquet: 1257 rows (OK)
# PWR_features.parquet: 1257 rows (OK)
# Deleting CEG_features.parquet: only 840 rows (expected at least 1257)
# LHX_features.parquet: 1257 rows (OK)
# PKG_features.parquet: 1257 rows (OK)
# WEC_features.parquet: 1257 rows (OK)
# EFX_features.parquet: 1257 rows (OK)
# OMC_features.parquet: 1257 rows (OK)
# AEP_features.parquet: 1257 rows (OK)
# PG_features.parquet: 1257 rows (OK)
# WMT_features.parquet: 1257 rows (OK)
# DRI_features.parquet: 1257 rows (OK)
# BKR_features.parquet: 1257 rows (OK)
# CBOE_features.parquet: 1257 rows (OK)
# ZBRA_features.parquet: 1257 rows (OK)
# INTC_features.parquet: 1257 rows (OK)
# SLB_features.parquet: 1257 rows (OK)
# TSLA_features.parquet: 1257 rows (OK)
# SCHW_features.parquet: 1257 rows (OK)
# ROK_features.parquet: 1257 rows (OK)
# EA_features.parquet: 1257 rows (OK)
# FFIV_features.parquet: 1257 rows (OK)
# PPG_features.parquet: 1257 rows (OK)
# CDW_features.parquet: 1257 rows (OK)
# LVS_features.parquet: 1257 rows (OK)
# ANET_features.parquet: 1257 rows (OK)
# CAH_features.parquet: 1257 rows (OK)
# BK_features.parquet: 1257 rows (OK)
# TEL_features.parquet: 1257 rows (OK)
# ECL_features.parquet: 1257 rows (OK)
# CCI_features.parquet: 1257 rows (OK)
# KEY_features.parquet: 1257 rows (OK)
# PTC_features.parquet: 1257 rows (OK)
# DXCM_features.parquet: 1257 rows (OK)
# IR_features.parquet: 1257 rows (OK)
# DHR_features.parquet: 1257 rows (OK)
# EXPE_features.parquet: 1257 rows (OK)
# BKNG_features.parquet: 1257 rows (OK)
# EPAM_features.parquet: 1257 rows (OK)
# TMO_features.parquet: 1257 rows (OK)
# RCL_features.parquet: 1257 rows (OK)
# V_features.parquet: 1257 rows (OK)
# AMAT_features.parquet: 1257 rows (OK)
# CTSH_features.parquet: 1257 rows (OK)
# CHD_features.parquet: 1257 rows (OK)
# VTR_features.parquet: 1257 rows (OK)
# ALGN_features.parquet: 1257 rows (OK)
# EMR_features.parquet: 1257 rows (OK)
# GOOGL_features.parquet: 1257 rows (OK)
# AMT_features.parquet: 1257 rows (OK)
# GL_features.parquet: 1257 rows (OK)
# LMT_features.parquet: 1257 rows (OK)
# CSGP_features.parquet: 1257 rows (OK)
# RTX_features.parquet: 1257 rows (OK)
# RVTY_features.parquet: 1257 rows (OK)
# LYB_features.parquet: 1257 rows (OK)
# FICO_features.parquet: 1257 rows (OK)
# BG_features.parquet: 1257 rows (OK)
# LKQ_features.parquet: 1257 rows (OK)
# Deleting PLTR_features.parquet: only 1168 rows (expected at least 1257)
# KMB_features.parquet: 1257 rows (OK)
# NWS_features.parquet: 1257 rows (OK)
# LYV_features.parquet: 1257 rows (OK)
# CRL_features.parquet: 1257 rows (OK)
# JBL_features.parquet: 1257 rows (OK)
# BIIB_features.parquet: 1257 rows (OK)
# FOXA_features.parquet: 1257 rows (OK)
# TAP_features.parquet: 1257 rows (OK)
# TXN_features.parquet: 1257 rows (OK)
# WAT_features.parquet: 1257 rows (OK)
# VST_features.parquet: 1257 rows (OK)
# EOG_features.parquet: 1257 rows (OK)
# NSC_features.parquet: 1257 rows (OK)
# BAC_features.parquet: 1257 rows (OK)
# BLK_features.parquet: 1257 rows (OK)
# GRMN_features.parquet: 1257 rows (OK)
# FSLR_features.parquet: 1257 rows (OK)
# VRSN_features.parquet: 1257 rows (OK)
# VLO_features.parquet: 1257 rows (OK)
# PODD_features.parquet: 1257 rows (OK)
# HSIC_features.parquet: 1257 rows (OK)
# BBY_features.parquet: 1257 rows (OK)
# CLX_features.parquet: 1257 rows (OK)
# MRNA_features.parquet: 1257 rows (OK)
# TECH_features.parquet: 1257 rows (OK)
# NRG_features.parquet: 1257 rows (OK)
# PRU_features.parquet: 1257 rows (OK)
# VZ_features.parquet: 1257 rows (OK)
# TTWO_features.parquet: 1257 rows (OK)
# KMI_features.parquet: 1257 rows (OK)
# GS_features.parquet: 1257 rows (OK)
# XEL_features.parquet: 1257 rows (OK)
# BX_features.parquet: 1257 rows (OK)
# SRE_features.parquet: 1257 rows (OK)
# STT_features.parquet: 1257 rows (OK)
# TSCO_features.parquet: 1257 rows (OK)
# EVRG_features.parquet: 1257 rows (OK)
# ROL_features.parquet: 1257 rows (OK)
# AMCR_features.parquet: 1257 rows (OK)
# HII_features.parquet: 1257 rows (OK)
# DAY_features.parquet: 1257 rows (OK)
# ELV_features.parquet: 1257 rows (OK)
# DVA_features.parquet: 1257 rows (OK)
# Deleting DASH_features.parquet: only 1119 rows (expected at least 1257)
# HSY_features.parquet: 1257 rows (OK)
# HBAN_features.parquet: 1257 rows (OK)
# KIM_features.parquet: 1257 rows (OK)
# WYNN_features.parquet: 1257 rows (OK)
# MDT_features.parquet: 1257 rows (OK)
# TPR_features.parquet: 1257 rows (OK)
# YUM_features.parquet: 1257 rows (OK)
# CSCO_features.parquet: 1257 rows (OK)
# DUK_features.parquet: 1257 rows (OK)
# NVDA_features.parquet: 1257 rows (OK)
# BAX_features.parquet: 1257 rows (OK)
# FOX_features.parquet: 1257 rows (OK)
# ISRG_features.parquet: 1257 rows (OK)
# MU_features.parquet: 1257 rows (OK)
# CSX_features.parquet: 1257 rows (OK)
# SMCI_features.parquet: 1257 rows (OK)
# CDNS_features.parquet: 1257 rows (OK)
# UAL_features.parquet: 1257 rows (OK)
# WBA_features.parquet: 1257 rows (OK)
# CVS_features.parquet: 1257 rows (OK)
# MA_features.parquet: 1257 rows (OK)
# AON_features.parquet: 1257 rows (OK)
# DGX_features.parquet: 1257 rows (OK)
# CPB_features.parquet: 1257 rows (OK)
# APA_features.parquet: 1257 rows (OK)
# A_features.parquet: 1257 rows (OK)
# STLD_features.parquet: 1257 rows (OK)
# PFG_features.parquet: 1257 rows (OK)
# HWM_features.parquet: 1257 rows (OK)
# MTB_features.parquet: 1257 rows (OK)
# DLTR_features.parquet: 1257 rows (OK)
# AWK_features.parquet: 1257 rows (OK)
# CL_features.parquet: 1257 rows (OK)
# CVX_features.parquet: 1257 rows (OK)
# NWSA_features.parquet: 1257 rows (OK)
# TT_features.parquet: 1257 rows (OK)
# COF_features.parquet: 1257 rows (OK)
# Deleting ABNB_features.parquet: only 1118 rows (expected at least 1257)
# OXY_features.parquet: 1257 rows (OK)
# BDX_features.parquet: 1257 rows (OK)
# IVZ_features.parquet: 1257 rows (OK)
# CAT_features.parquet: 1257 rows (OK)
# MTCH_features.parquet: 1257 rows (OK)
# DVN_features.parquet: 1257 rows (OK)
# COR_features.parquet: 1257 rows (OK)
# PSA_features.parquet: 1257 rows (OK)
# BALL_features.parquet: 1257 rows (OK)
# KO_features.parquet: 1257 rows (OK)
# META_features.parquet: 1257 rows (OK)
# PCG_features.parquet: 1257 rows (OK)
# OKE_features.parquet: 1257 rows (OK)
# AMP_features.parquet: 1257 rows (OK)
# CMS_features.parquet: 1257 rows (OK)
# J_features.parquet: 1257 rows (OK)
# ERIE_features.parquet: 1257 rows (OK)
# AKAM_features.parquet: 1257 rows (OK)
# AES_features.parquet: 1257 rows (OK)
# Deleting GEV_features.parquet: only 289 rows (expected at least 1257)
# MMC_features.parquet: 1257 rows (OK)
# BRO_features.parquet: 1257 rows (OK)
# CMG_features.parquet: 1257 rows (OK)
# AMD_features.parquet: 1257 rows (OK)
# MET_features.parquet: 1257 rows (OK)
# CTAS_features.parquet: 1257 rows (OK)
# PGR_features.parquet: 1257 rows (OK)
# TGT_features.parquet: 1257 rows (OK)
# RSG_features.parquet: 1257 rows (OK)
# TPL_features.parquet: 1257 rows (OK)
# ADM_features.parquet: 1257 rows (OK)
# MOS_features.parquet: 1257 rows (OK)
# DPZ_features.parquet: 1257 rows (OK)
# HD_features.parquet: 1257 rows (OK)
# ESS_features.parquet: 1257 rows (OK)
# NOW_features.parquet: 1257 rows (OK)
# APTV_features.parquet: 1257 rows (OK)
# EL_features.parquet: 1257 rows (OK)
# CRWD_features.parquet: 1257 rows (OK)
# NDAQ_features.parquet: 1257 rows (OK)
# MO_features.parquet: 1257 rows (OK)
# CI_features.parquet: 1257 rows (OK)
# NXPI_features.parquet: 1257 rows (OK)
# NOC_features.parquet: 1257 rows (OK)
# HOLX_features.parquet: 1257 rows (OK)
# FIS_features.parquet: 1257 rows (OK)
# APO_features.parquet: 1257 rows (OK)
# MAA_features.parquet: 1257 rows (OK)
# SO_features.parquet: 1257 rows (OK)
# JNJ_features.parquet: 1257 rows (OK)
# O_features.parquet: 1257 rows (OK)
# HCA_features.parquet: 1257 rows (OK)
# CRM_features.parquet: 1257 rows (OK)
# FITB_features.parquet: 1257 rows (OK)
# ON_features.parquet: 1257 rows (OK)
# PEG_features.parquet: 1257 rows (OK)
# KKR_features.parquet: 1257 rows (OK)
# ADBE_features.parquet: 1257 rows (OK)
# AVGO_features.parquet: 1257 rows (OK)
# ACGL_features.parquet: 1257 rows (OK)
# PANW_features.parquet: 1257 rows (OK)
# EQR_features.parquet: 1257 rows (OK)
# GM_features.parquet: 1257 rows (OK)
# AFL_features.parquet: 1257 rows (OK)
# MKC_features.parquet: 1257 rows (OK)
# FANG_features.parquet: 1257 rows (OK)
# BR_features.parquet: 1257 rows (OK)
# KDP_features.parquet: 1257 rows (OK)
# CB_features.parquet: 1257 rows (OK)
# MPC_features.parquet: 1257 rows (OK)
# DAL_features.parquet: 1257 rows (OK)
# RJF_features.parquet: 1257 rows (OK)
# APD_features.parquet: 1257 rows (OK)
# ES_features.parquet: 1257 rows (OK)
# AIZ_features.parquet: 1257 rows (OK)
# WSM_features.parquet: 1257 rows (OK)
# LIN_features.parquet: 1257 rows (OK)
# WBD_features.parquet: 1257 rows (OK)
# CTRA_features.parquet: 1257 rows (OK)
# EG_features.parquet: 1257 rows (OK)
# FI_features.parquet: 1257 rows (OK)
# MNST_features.parquet: 1257 rows (OK)
# KHC_features.parquet: 1257 rows (OK)
# ZTS_features.parquet: 1257 rows (OK)
# IFF_features.parquet: 1257 rows (OK)
# SBUX_features.parquet: 1257 rows (OK)
# WRB_features.parquet: 1257 rows (OK)
# MMM_features.parquet: 1257 rows (OK)
# MCK_features.parquet: 1257 rows (OK)
# IT_features.parquet: 1257 rows (OK)
# GOOG_features.parquet: 1257 rows (OK)
# ARE_features.parquet: 1257 rows (OK)
# JCI_features.parquet: 1257 rows (OK)
# D_features.parquet: 1257 rows (OK)
# ETR_features.parquet: 1257 rows (OK)
# XYL_features.parquet: 1257 rows (OK)
# CMI_features.parquet: 1257 rows (OK)
# FTV_features.parquet: 1257 rows (OK)
# DTE_features.parquet: 1257 rows (OK)
# SNA_features.parquet: 1257 rows (OK)
# KMX_features.parquet: 1257 rows (OK)
# SYY_features.parquet: 1257 rows (OK)
# LNT_features.parquet: 1257 rows (OK)
# T_features.parquet: 1257 rows (OK)
# WTW_features.parquet: 1257 rows (OK)
# CNC_features.parquet: 1257 rows (OK)
# IEX_features.parquet: 1257 rows (OK)
# TRV_features.parquet: 1257 rows (OK)
# CTVA_features.parquet: 1257 rows (OK)
# SWK_features.parquet: 1257 rows (OK)
# IP_features.parquet: 1257 rows (OK)
# STE_features.parquet: 1257 rows (OK)
# Deleting SOLV_features.parquet: only 289 rows (expected at least 1257)
# AAPL_features.parquet: 1257 rows (OK)
# UNP_features.parquet: 1257 rows (OK)
# MCO_features.parquet: 1257 rows (OK)
# KEYS_features.parquet: 1257 rows (OK)
# INTU_features.parquet: 1257 rows (OK)
# MOH_features.parquet: 1257 rows (OK)
# NVR_features.parquet: 1257 rows (OK)
# EIX_features.parquet: 1257 rows (OK)
# LDOS_features.parquet: 1257 rows (OK)
# EW_features.parquet: 1257 rows (OK)
# CF_features.parquet: 1257 rows (OK)
# MSI_features.parquet: 1257 rows (OK)
# CINF_features.parquet: 1257 rows (OK)
# ORCL_features.parquet: 1257 rows (OK)
# PCAR_features.parquet: 1257 rows (OK)
# PLD_features.parquet: 1257 rows (OK)
# INCY_features.parquet: 1257 rows (OK)
# TXT_features.parquet: 1257 rows (OK)
# HUM_features.parquet: 1257 rows (OK)
# UDR_features.parquet: 1257 rows (OK)
# MPWR_features.parquet: 1257 rows (OK)
# Deleting EXE_features.parquet: only 1077 rows (expected at least 1257)
# CARR_features.parquet: 1257 rows (OK)
# HRL_features.parquet: 1257 rows (OK)
# AME_features.parquet: 1257 rows (OK)
# SYF_features.parquet: 1257 rows (OK)
# K_features.parquet: 1257 rows (OK)
# MCD_features.parquet: 1257 rows (OK)
# LRCX_features.parquet: 1257 rows (OK)
# NEE_features.parquet: 1257 rows (OK)
# ATO_features.parquet: 1257 rows (OK)
# WMB_features.parquet: 1257 rows (OK)
# STZ_features.parquet: 1257 rows (OK)
# FTNT_features.parquet: 1257 rows (OK)
# DG_features.parquet: 1257 rows (OK)
# VRSK_features.parquet: 1257 rows (OK)
# Deleting MSFT_features.parquet: only 72 rows (expected at least 1257)
# ADI_features.parquet: 1257 rows (OK)
# HIG_features.parquet: 1257 rows (OK)
# TJX_features.parquet: 1257 rows (OK)
# IBM_features.parquet: 1257 rows (OK)
# MLM_features.parquet: 1257 rows (OK)
# GPN_features.parquet: 1257 rows (OK)
# MCHP_features.parquet: 1257 rows (OK)
# POOL_features.parquet: 1257 rows (OK)

# %%
df = df.iloc[:-1]
df.to_parquet("model_outputs/TechnicalScorer/AAPL.parquet")
print(df.iloc[-1, df.columns.get_loc('analyst_targets')])
print(len(df))
# Out:
# {"current_price": 195.9312, "median_target": 228.75928, "low_target": 170.62, "high_target": 300.0}
# 1256

# %%
df.index
# Out:
# DatetimeIndex(['2020-05-26', '2020-05-27', '2020-05-28', '2020-05-29',
#                '2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-08',
#                ...
#                '2025-05-12', '2025-05-13', '2025-05-14', '2025-05-15',
#                '2025-05-16', '2025-05-19', '2025-05-20', '2025-05-21',
#                '2025-05-22', '2025-05-23'],
#               dtype='datetime64[ns]', name='Date', length=1257, freq=None)

# %%
print(df.iloc[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/98/yy10zc2d3c90rnbpzgc094_80000gn/T/ipykernel_12334/1082847965.py in ?()
# ----> 1 print(df.Date.iloc[-1])
#
# ~/miniconda3/envs/trading-advisor-py39/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df.iloc[-2, df.columns.get_loc('analyst_targets')] = df.iloc[-1]['analyst_targets']

# %%
print(df.iloc[-2, df.columns.get_loc('analyst_targets')])
# Out:
# {"current_price": 195.9312, "median_target": 228.75928, "low_target": 170.62, "high_target": 300.0}

# %%
df = df.iloc[:-1]
df.to_parquet("features/AAPL_features.parquet")
print(df.iloc[-1, df.columns.get_loc('analyst_targets')])
# Out:
# {"current_price": 195.9312, "median_target": 228.75928, "low_target": 170.62, "high_target": 300.0}

# %%
df = pd.read_parquet("features/AAPL_features.parquet")
print(df.iloc[-1]['analyst_targets'])  # This should be the value you manually set in the previous second-to-last row
# Out:
# {"current_price": 195.9312, "median_target": 228.75928, "low_target": 170.62, "high_target": 300.0}

# %%
print(df.iloc[-2]['analyst_targets'])
# Out:
# {"current_price": 195.9312, "median_target": 228.75928, "low_target": 170.62, "high_target": 300.0}

# %%
print(df.iloc[-3]['analyst_targets'])
# Out:
# None
